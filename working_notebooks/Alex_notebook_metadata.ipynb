# %%
import pandas as pd
import pickle
import matplotlib.pyplot as plt

from surprise import Dataset, Reader, accuracy
from surprise.model_selection import cross_validate, train_test_split, GridSearchCV
from surprise.prediction_algorithms import SVD, SVDpp, NMF, BaselineOnly, NormalPredictor

# %matplotlib inline

# %%
#Import our meta data 
import gzip

def parse(path):
  g = gzip.open(path, 'rb')
  for l in g:
    yield eval(l)

def getDF(path):
  i = 0
  df = {}
  for d in parse(path):
    df[i] = d
    i += 1
  return pd.DataFrame.from_dict(df, orient='index')

meta_data_df = getDF('Data/meta_Beauty.json.gz')

# %%
meta_data_df.head(3)
# Out:
#          asin                                        description  \
# 0  0205616461  As we age, our once youthful, healthy skin suc...
# 1  0558925278  Mineral Powder Brush--Apply powder or mineral ...
# 2  0733001998  From the Greek island of Chios, this Mastiha b...
#
#                                                title  \
# 0  Bio-Active Anti-Aging Serum (Firming Ultra-Hyd...
# 1  Eco Friendly Ecotools Quality Natural Bamboo C...
# 2                                Mastiha Body Lotion
#
#                                                imUrl  \
# 0  http://ecx.images-amazon.com/images/I/41DecrGO...
# 1  http://ecx.images-amazon.com/images/I/51L%2BzY...
# 2  http://ecx.images-amazon.com/images/I/311WK5y1...
#
#                             salesRank  \
# 0  {'Health & Personal Care': 461765}
# 1                  {'Beauty': 402875}
# 2                  {'Beauty': 540255}
#
#                                           categories  price related brand
# 0  [[Beauty, Skin Care, Face, Creams & Moisturize...    NaN     NaN   NaN
# 1  [[Beauty, Tools & Accessories, Makeup Brushes ...    NaN     NaN   NaN
# 2  [[Beauty, Skin Care, Body, Moisturizers, Lotio...    NaN     NaN   NaN

# %%
reviews_df = pd.read_json("Data/reviews_Beauty_5.json.gz",lines=True)

# %%
unique_asins_in_reviews = list(reviews_df.asin.unique())
len(unique_asins_in_reviews)
# Out:
# 12101

# %%
meta_data_df_cleaned = meta_data_df[meta_data_df.asin.isin(unique_asins_in_reviews)]
meta_data_df_cleaned
# Out:
#               asin                                        description  \
# 115     7806397051  An extensive range of 15 multiple vibrant long...
# 179     9759091062  Xtreme Brite  Brightening gel is a highly conc...
# 192     9788072216  Prada Candy By Prada Eau De Parfum Spray 1.7 O...
# 555     9790790961  Versace Bright Crystal Perfume for Women 3 oz ...
# 587     9790794231  STELLA For Women By STELLA MCCARTNEY 1.7 oz ED...
# ...            ...                                                ...
# 259140  B00L5JHZJO  We Only Source Our 100% Organic & Pure Argan O...
# 259143  B00L6Q3BH6  Lip stain that goes on liquid and dries comple...
# 259170  B00LCEROA2                                                NaN
# 259179  B00LG63DOM  The Secret to Younger Looking Skin Vitamin C S...
# 259193  B00LLPT4HI  Ingredients:\n100% Pure, Unrefined, Organic Af...
#
#                                                     title  \
# 115     WAWO 15 Color Professionl Makeup Eyeshadow Cam...
# 179                     Xtreme Brite Brightening Gel 1oz.
# 192     Prada Candy By Prada Eau De Parfum Spray 1.7 O...
# 555     Versace Bright Crystal Eau de Toilette Spray f...
# 587                               Stella McCartney Stella
# ...                                                   ...
# 259140  Moroccan Argan Oil - For Hair, Face, Skin, &am...
# 259143                     LIME CRIME Velvetines - Wicked
# 259170                     Dr Song Rosehip Oil 4oz (4 oz)
# 259179  VITAMIN C SERUM 20% with Hyaluronic Acid For Y...
# 259193  100% Organic Raw Unrefined African Shea Butter...
#
#                                                     imUrl  \
# 115     http://ecx.images-amazon.com/images/I/41Rn18Oe...
# 179     http://ecx.images-amazon.com/images/I/41QWW9v1...
# 192     http://ecx.images-amazon.com/images/I/51iT2k6L...
# 555     http://ecx.images-amazon.com/images/I/418LYGLE...
# 587     http://ecx.images-amazon.com/images/I/31L2n60J...
# ...                                                   ...
# 259140  http://ecx.images-amazon.com/images/I/41kTNm0k...
# 259143  http://ecx.images-amazon.com/images/I/41q7jpgt...
# 259170  http://ecx.images-amazon.com/images/I/412qdoPc...
# 259179  http://ecx.images-amazon.com/images/I/31JTTyCU...
# 259193  http://ecx.images-amazon.com/images/I/41up5%2B...
#
#                                salesRank  \
# 115                    {'Beauty': 10486}
# 179                    {'Beauty': 52254}
# 192                    {'Beauty': 78916}
# 555                      {'Beauty': 764}
# 587                   {'Beauty': 142503}
# ...                                  ...
# 259140                   {'Beauty': 120}
# 259143  {'Health & Personal Care': 3006}
# 259170                  {'Beauty': 7597}
# 259179                 {'Beauty': 58521}
# 259193                  {'Beauty': 1265}
#
#                                                categories  price  \
# 115     [[Beauty, Makeup, Face, Concealers & Neutraliz...   5.04
# 179     [[Beauty, Hair Care, Styling Products, Creams,...  19.99
# 192         [[Beauty, Fragrance, Women's, Eau de Parfum]]  65.86
# 555       [[Beauty, Fragrance, Women's, Eau de Toilette]]  52.33
# 587         [[Beauty, Fragrance, Women's, Eau de Parfum]]    NaN
# ...                                                   ...    ...
# 259140    [[Beauty, Skin Care, Body, Moisturizers, Oils]]  14.99
# 259143                 [[Beauty, Makeup, Lips, Lipstick]]  27.50
# 259170         [[Beauty, Skin Care, Face, Oils & Serums]]  19.99
# 259179  [[Beauty, Skin Care, Face, Creams & Moisturize...  36.00
# 259193  [[Beauty, Skin Care, Body, Moisturizers, Lotio...   9.97
#
#                                                   related           brand
# 115     {'also_bought': ['B00KR26VFE', 'B00E7LQHZ0', '...            COKA
# 179     {'also_bought': ['B0054GLD1U', 'B003BRZCUC', '...    Xtreme Brite
# 192     {'also_bought': ['B006C5OHSI', 'B006P14842', '...           Prada
# 555     {'also_bought': ['B007P7OPQQ', 'B0017JT658', '...         Versace
# 587     {'also_bought': ['B0019M21OQ', 'B000E7YM8K', '...             NaN
# ...                                                   ...             ...
# 259140  {'also_bought': ['B00JSLU7MS', 'B00GZ0WFQG', '...  Natural Beauty
# 259143  {'also_bought': ['B00JH29K6M', 'B00JH2B182', '...      Lime Crime
# 259170  {'also_bought': ['B00LNVW1IE', 'B00JYKGFWY', '...             NaN
# 259179  {'also_bought': ['B00JJOEV9Y', 'B00KWP8ZIM', '...             NaN
# 259193  {'also_bought': ['B00LFPS0CY', 'B00KZNOHTW', '...             NaN
#
# [12101 rows x 9 columns]
